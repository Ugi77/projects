# %% [markdown]
# ### Imports

# %%
import pandas as pd
import os
import seaborn as sns

from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype

# %% [markdown]
# ### Concatenate 10 datasets

# %%
# current working directory
path = os.getcwd()

# show all files in current working directory
files = os.listdir(path)
files
# Out:
# ['.ipynb_checkpoints',
#  'dataframe_albuquerque.xlsx',
#  'dataframe_colorado.xlsx',
#  'dataframe_indianapolis.xlsx',
#  'dataframe_las_vegas.xlsx',
#  'dataframe_miami.xlsx',
#  'dataframe_new_york.xlsx',
#  'dataframe_philadelphia.xlsx',
#  'dataframe_san_diego.xlsx',
#  'dataframe_san_francisco.xlsx',
#  'dataframe_washington.xlsx',
#  'RealEstateDataCleaning.ipynb']

# %%
files_needed = ['dataframe_albuquerque.xlsx',
 'dataframe_colorado.xlsx',
 'dataframe_indianapolis.xlsx',
 'dataframe_las_vegas.xlsx',
 'dataframe_miami.xlsx',
 'dataframe_new_york.xlsx',
 'dataframe_philadelphia.xlsx',
 'dataframe_san_diego.xlsx',
 'dataframe_san_francisco.xlsx',
 'dataframe_washington.xlsx']

# %%
len(files_needed)
# Out:
# 10

# %%
# initialize dataframe
df_combined = pd.DataFrame()

for f in files_needed:
    df_combined = df_combined.append(pd.read_excel(f, 'Sheet1'))

# %%
df_combined
# Out:
#                    Address Bedrooms Bathrooms        Area Year Built  \
# 0      9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1         460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2    1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3      5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4    2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
# ..                     ...      ...       ...         ...        ...
# 855      1715 Euclid St NW   6 Beds       NaN         NaN       1906
# 856           2015 Q St NW   6 Beds       NaN  5,285 sqft       1925
# 857     922 24th St NW #5B    1 Bed    1 Bath    743 sqft       1962
# 858   1099 22nd St NW #401   3 Beds   3 Baths  2,078 sqft       1985
# 859   2125 14th St NW #309   Studio    1 Bath    538 sqft       2007
#
#               Parking       Price     Location
# 0        2 Car Garage    $330,000  Albuquerque
# 1        2 Car Garage    $289,900  Albuquerque
# 2             No Info    $155,000  Albuquerque
# 3        2 Car Garage    $269,900  Albuquerque
# 4        2 Car Garage    $450,000  Albuquerque
# ..                ...         ...          ...
# 855      Open Parking  $1,900,000   Washington
# 856  2 Parking Spaces  $2,750,000   Washington
# 857      1 Car Garage    $319,500   Washington
# 858      2 Car Garage  $1,375,000   Washington
# 859              None    $387,000   Washington
#
# [8755 rows x 8 columns]

# %% [markdown]
# # Data Cleaning Process

# %% [markdown]
# - Check for missing Data
#
# - Reset/Change Index number (e.g. row number)
#
# - Check Doubles
#
# ---
#
# - Change Price Column
#
# - Price Data : Cut "$" in Price
#
# - Price Data : Cut "," in Price
# ---
#
# - Change Area Column
#
# - Area Data : Cut "sqft" string element
#
# - Area Data : Cut "," string element
# ---
#
# - Bedrooms Data : Cut 'Beds' string element
#
# - Bedrooms Data: "Studio" = 1 room
#
# - Bathrooms Data : Cut 'Baths' string element
# ---
#
# - Parking Data : yes/no
# ---
#
# - Convert all numbers to integers
# ---
#
# - New Column "price/sqft"
# - Check for Outliers
# - Save to Excel

# %% [markdown]
# ### Check for missing data

# %%
df_combined.info()
# data missing for beds, baths, etc, looks complete for Address, Location
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8755 entries, 0 to 859
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Address     8755 non-null   object
#  1   Bedrooms    8255 non-null   object
#  2   Bathrooms   8145 non-null   object
#  3   Area        8020 non-null   object
#  4   Year Built  8333 non-null   object
#  5   Parking     8263 non-null   object
#  6   Price       8752 non-null   object
#  7   Location    8755 non-null   object
# dtypes: object(8)
# memory usage: 615.6+ KB

# %%
# check for at least 1 missing value in a row
df_combined[df_combined.isna().any(axis = 1)]
# Out:
#                      Address Bedrooms Bathrooms        Area Year Built  \
# 370            Pajarito Mesa      NaN       NaN         NaN        NaN
# 376    1033 Forrester Ave NW   Studio       NaN    600 sqft       1977
# 400    1920 Broadway Blvd SE   2 Beds    1 Bath         NaN       1962
# 402  1990 1/2 Cherokee Rd NW      NaN       NaN         NaN        NaN
# 404         1301 Iron Ave SW   2 Beds   2 Baths         NaN       1916
# ..                       ...      ...       ...         ...        ...
# 798   235 Emerson St NW #101    1 Bed    1 Bath         NaN       1929
# 817         2308 Tracy Pl NW   6 Beds   6 Baths         NaN       1919
# 818        2017 Rear 2 St NE      NaN       NaN         NaN        NaN
# 855        1715 Euclid St NW   6 Beds       NaN         NaN       1906
# 856             2015 Q St NW   6 Beds       NaN  5,285 sqft       1925
#
#               Parking       Price     Location
# 370               NaN     $13,000  Albuquerque
# 376           No Info    $205,000  Albuquerque
# 400           No Info    $245,000  Albuquerque
# 402               NaN    $175,000  Albuquerque
# 404           No Info    $355,000  Albuquerque
# ..                ...         ...          ...
# 798      Open Parking    $209,900   Washington
# 817            Garage  $4,888,000   Washington
# 818               NaN    $295,000   Washington
# 855      Open Parking  $1,900,000   Washington
# 856  2 Parking Spaces  $2,750,000   Washington
#
# [929 rows x 8 columns]

# %%
# check for missing values in a heat map
sns.heatmap(df_combined.isna(), yticklabels = False, cbar = False, cmap = 'BuGn')
# unsure why heatmap not visualizing...
# Out:
# <AxesSubplot:>

# %%
# drop all entries where 1 value (in a row) is missing
# need to restate variable in order to propery overwrite
df_combined = df_combined.dropna()

# %%
# now all rows have full data
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7826 entries, 0 to 859
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Address     7826 non-null   object
#  1   Bedrooms    7826 non-null   object
#  2   Bathrooms   7826 non-null   object
#  3   Area        7826 non-null   object
#  4   Year Built  7826 non-null   object
#  5   Parking     7826 non-null   object
#  6   Price       7826 non-null   object
#  7   Location    7826 non-null   object
# dtypes: object(8)
# memory usage: 550.3+ KB

# %% [markdown]
# ###  Reset/Change Index

# %%
# since all files were combined the row numbers are not consecutive through the dataframe
# now we fix that
df_combined = df_combined.reset_index(drop = True)

# %%
# now there is a unique index for each row
df_combined
# Out:
#                     Address Bedrooms Bathrooms        Area Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4     2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
# ...                     ...      ...       ...         ...        ...
# 7821  2232 Mount View Pl SE   3 Beds   4 Baths  1,200 sqft       1933
# 7822   1111 25th St NW #304   2 Beds    1 Bath    835 sqft       2005
# 7823     922 24th St NW #5B    1 Bed    1 Bath    743 sqft       1962
# 7824   1099 22nd St NW #401   3 Beds   3 Baths  2,078 sqft       1985
# 7825   2125 14th St NW #309   Studio    1 Bath    538 sqft       2007
#
#            Parking       Price     Location
# 0     2 Car Garage    $330,000  Albuquerque
# 1     2 Car Garage    $289,900  Albuquerque
# 2          No Info    $155,000  Albuquerque
# 3     2 Car Garage    $269,900  Albuquerque
# 4     2 Car Garage    $450,000  Albuquerque
# ...            ...         ...          ...
# 7821  Open Parking    $829,900   Washington
# 7822  1 Car Garage    $549,900   Washington
# 7823  1 Car Garage    $319,500   Washington
# 7824  2 Car Garage  $1,375,000   Washington
# 7825          None    $387,000   Washington
#
# [7826 rows x 8 columns]

# %% [markdown]
# ###  Check for Outliers and Doubles

# %%
# check for duplicates, outputs number of duplicates
df_combined.duplicated().sum()
# Out:
# 1580

# %%
df_combined.loc[df_combined.duplicated(), :]
# can additionally cross-check via manual "find all" of example address in raw data file
# Out:
#                           Address Bedrooms Bathrooms        Area Year Built  \
# 80            1829 Illinois St NE   5 Beds   2 Baths  1,797 sqft       1954
# 81          9109 Crestwood Ave NE   3 Beds   3 Baths  2,183 sqft       1963
# 82               3401 Cagua Dr NE   3 Beds   2 Baths  1,831 sqft       1955
# 83               1325 Hertz Dr SE   3 Beds   3 Baths  3,335 sqft       1975
# 84             1020 Indiana St SE   4 Beds   2 Baths  1,950 sqft       1953
# ...                           ...      ...       ...         ...        ...
# 7748         525 Water St SW #420   3 Beds   3 Baths  1,724 sqft       2016
# 7749         1032 Lamont St NW #A   3 Beds   3 Baths  1,464 sqft       1907
# 7750          2403 Savannah St SE   3 Beds   2 Baths  1,405 sqft       1950
# 7751          7508 Eastern Ave NW   3 Beds   3 Baths  1,088 sqft       1948
# 7798  2660 Connecticut Ave NW #7C   3 Beds   4 Baths  4,648 sqft       1928
#
#                Parking       Price     Location
# 80        1 Car Garage    $225,000  Albuquerque
# 81        2 Car Garage    $320,000  Albuquerque
# 82    2 Carport Spaces    $269,000  Albuquerque
# 83        2 Car Garage    $435,000  Albuquerque
# 84              Garage    $299,900  Albuquerque
# ...                ...         ...          ...
# 7748      2 Car Garage  $1,375,000   Washington
# 7749      Open Parking    $749,000   Washington
# 7750     1 Open Spaces    $449,900   Washington
# 7751      Open Parking    $599,000   Washington
# 7798      3 Car Garage  $4,995,000   Washington
#
# [1580 rows x 8 columns]

# %%
# remove duplicate entries (1580 rows!)
# If you want to preview this first, run: df_combined.drop_duplicates() and don't assign to variable
# so then it would not be overwritten
df_combined = df_combined.drop_duplicates()

# %%
df_combined
# Out:
#                     Address Bedrooms Bathrooms        Area Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4     2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
# ...                     ...      ...       ...         ...        ...
# 7821  2232 Mount View Pl SE   3 Beds   4 Baths  1,200 sqft       1933
# 7822   1111 25th St NW #304   2 Beds    1 Bath    835 sqft       2005
# 7823     922 24th St NW #5B    1 Bed    1 Bath    743 sqft       1962
# 7824   1099 22nd St NW #401   3 Beds   3 Baths  2,078 sqft       1985
# 7825   2125 14th St NW #309   Studio    1 Bath    538 sqft       2007
#
#            Parking       Price     Location
# 0     2 Car Garage    $330,000  Albuquerque
# 1     2 Car Garage    $289,900  Albuquerque
# 2          No Info    $155,000  Albuquerque
# 3     2 Car Garage    $269,900  Albuquerque
# 4     2 Car Garage    $450,000  Albuquerque
# ...            ...         ...          ...
# 7821  Open Parking    $829,900   Washington
# 7822  1 Car Garage    $549,900   Washington
# 7823  1 Car Garage    $319,500   Washington
# 7824  2 Car Garage  $1,375,000   Washington
# 7825          None    $387,000   Washington
#
# [6246 rows x 8 columns]

# %%
# and now reset index
df_combined = df_combined.reset_index(drop = True)

# %%
df_combined
# Out:
#                     Address Bedrooms Bathrooms        Area Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4     2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
# ...                     ...      ...       ...         ...        ...
# 6241  2232 Mount View Pl SE   3 Beds   4 Baths  1,200 sqft       1933
# 6242   1111 25th St NW #304   2 Beds    1 Bath    835 sqft       2005
# 6243     922 24th St NW #5B    1 Bed    1 Bath    743 sqft       1962
# 6244   1099 22nd St NW #401   3 Beds   3 Baths  2,078 sqft       1985
# 6245   2125 14th St NW #309   Studio    1 Bath    538 sqft       2007
#
#            Parking       Price     Location
# 0     2 Car Garage    $330,000  Albuquerque
# 1     2 Car Garage    $289,900  Albuquerque
# 2          No Info    $155,000  Albuquerque
# 3     2 Car Garage    $269,900  Albuquerque
# 4     2 Car Garage    $450,000  Albuquerque
# ...            ...         ...          ...
# 6241  Open Parking    $829,900   Washington
# 6242  1 Car Garage    $549,900   Washington
# 6243  1 Car Garage    $319,500   Washington
# 6244  2 Car Garage  $1,375,000   Washington
# 6245          None    $387,000   Washington
#
# [6246 rows x 8 columns]

# %% [markdown]
# ###  Change Price Column

# %%
# rename price column and update existing dataframe
df_combined = df_combined.rename(columns = {"Price":"Price($)"})
df_combined
# Out:
#                     Address Bedrooms Bathrooms        Area Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4     2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
# ...                     ...      ...       ...         ...        ...
# 6241  2232 Mount View Pl SE   3 Beds   4 Baths  1,200 sqft       1933
# 6242   1111 25th St NW #304   2 Beds    1 Bath    835 sqft       2005
# 6243     922 24th St NW #5B    1 Bed    1 Bath    743 sqft       1962
# 6244   1099 22nd St NW #401   3 Beds   3 Baths  2,078 sqft       1985
# 6245   2125 14th St NW #309   Studio    1 Bath    538 sqft       2007
#
#            Parking    Price($)     Location
# 0     2 Car Garage    $330,000  Albuquerque
# 1     2 Car Garage    $289,900  Albuquerque
# 2          No Info    $155,000  Albuquerque
# 3     2 Car Garage    $269,900  Albuquerque
# 4     2 Car Garage    $450,000  Albuquerque
# ...            ...         ...          ...
# 6241  Open Parking    $829,900   Washington
# 6242  1 Car Garage    $549,900   Washington
# 6243  1 Car Garage    $319,500   Washington
# 6244  2 Car Garage  $1,375,000   Washington
# 6245          None    $387,000   Washington
#
# [6246 rows x 8 columns]

# %% [markdown]
# ###  Price Data : Cut '$' in Price

# %%
# we want to override only the Price($) column, not the whole dataframe
df_combined['Price($)'] = df_combined['Price($)'].str.strip('$')

# %%
df_combined
# Out:
#                     Address Bedrooms Bathrooms        Area Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4     2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
# ...                     ...      ...       ...         ...        ...
# 6241  2232 Mount View Pl SE   3 Beds   4 Baths  1,200 sqft       1933
# 6242   1111 25th St NW #304   2 Beds    1 Bath    835 sqft       2005
# 6243     922 24th St NW #5B    1 Bed    1 Bath    743 sqft       1962
# 6244   1099 22nd St NW #401   3 Beds   3 Baths  2,078 sqft       1985
# 6245   2125 14th St NW #309   Studio    1 Bath    538 sqft       2007
#
#            Parking   Price($)     Location
# 0     2 Car Garage    330,000  Albuquerque
# 1     2 Car Garage    289,900  Albuquerque
# 2          No Info    155,000  Albuquerque
# 3     2 Car Garage    269,900  Albuquerque
# 4     2 Car Garage    450,000  Albuquerque
# ...            ...        ...          ...
# 6241  Open Parking    829,900   Washington
# 6242  1 Car Garage    549,900   Washington
# 6243  1 Car Garage    319,500   Washington
# 6244  2 Car Garage  1,375,000   Washington
# 6245          None    387,000   Washington
#
# [6246 rows x 8 columns]

# %% [markdown]
# ###  Price Data : Cut ',' in Price

# %%
# can use strip or replace function
df_combined['Price($)'] = df_combined['Price($)'].str.replace(',', '')
df_combined
# Out:
#                     Address Bedrooms Bathrooms        Area Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4     2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
# ...                     ...      ...       ...         ...        ...
# 6241  2232 Mount View Pl SE   3 Beds   4 Baths  1,200 sqft       1933
# 6242   1111 25th St NW #304   2 Beds    1 Bath    835 sqft       2005
# 6243     922 24th St NW #5B    1 Bed    1 Bath    743 sqft       1962
# 6244   1099 22nd St NW #401   3 Beds   3 Baths  2,078 sqft       1985
# 6245   2125 14th St NW #309   Studio    1 Bath    538 sqft       2007
#
#            Parking Price($)     Location
# 0     2 Car Garage   330000  Albuquerque
# 1     2 Car Garage   289900  Albuquerque
# 2          No Info   155000  Albuquerque
# 3     2 Car Garage   269900  Albuquerque
# 4     2 Car Garage   450000  Albuquerque
# ...            ...      ...          ...
# 6241  Open Parking   829900   Washington
# 6242  1 Car Garage   549900   Washington
# 6243  1 Car Garage   319500   Washington
# 6244  2 Car Garage  1375000   Washington
# 6245          None   387000   Washington
#
# [6246 rows x 8 columns]

# %% [markdown]
# ### Change Area Column

# %%
# rename area column and update existing dataframe
df_combined = df_combined.rename(columns = {"Area":"Area(Sqft)"})
df_combined
# Out:
#                     Address Bedrooms Bathrooms  Area(Sqft) Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths  2,000 sqft       1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths  2,212 sqft       2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath    815 sqft       1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths  1,600 sqft       1977
# 4     2804 Charleston St NE   4 Beds   3 Baths  2,445 sqft       1963
# ...                     ...      ...       ...         ...        ...
# 6241  2232 Mount View Pl SE   3 Beds   4 Baths  1,200 sqft       1933
# 6242   1111 25th St NW #304   2 Beds    1 Bath    835 sqft       2005
# 6243     922 24th St NW #5B    1 Bed    1 Bath    743 sqft       1962
# 6244   1099 22nd St NW #401   3 Beds   3 Baths  2,078 sqft       1985
# 6245   2125 14th St NW #309   Studio    1 Bath    538 sqft       2007
#
#            Parking Price($)     Location
# 0     2 Car Garage   330000  Albuquerque
# 1     2 Car Garage   289900  Albuquerque
# 2          No Info   155000  Albuquerque
# 3     2 Car Garage   269900  Albuquerque
# 4     2 Car Garage   450000  Albuquerque
# ...            ...      ...          ...
# 6241  Open Parking   829900   Washington
# 6242  1 Car Garage   549900   Washington
# 6243  1 Car Garage   319500   Washington
# 6244  2 Car Garage  1375000   Washington
# 6245          None   387000   Washington
#
# [6246 rows x 8 columns]

# %% [markdown]
# ###  Area Data : Cut 'sqft' string element

# %%
# also white space prior to sqft
df_combined['Area(Sqft)'] = df_combined['Area(Sqft)'].str.strip(' sqft')
df_combined
# Out:
#                     Address Bedrooms Bathrooms Area(Sqft) Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths      2,000       1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths      2,212       2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath        815       1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths      1,600       1977
# 4     2804 Charleston St NE   4 Beds   3 Baths      2,445       1963
# ...                     ...      ...       ...        ...        ...
# 6241  2232 Mount View Pl SE   3 Beds   4 Baths      1,200       1933
# 6242   1111 25th St NW #304   2 Beds    1 Bath        835       2005
# 6243     922 24th St NW #5B    1 Bed    1 Bath        743       1962
# 6244   1099 22nd St NW #401   3 Beds   3 Baths      2,078       1985
# 6245   2125 14th St NW #309   Studio    1 Bath        538       2007
#
#            Parking Price($)     Location
# 0     2 Car Garage   330000  Albuquerque
# 1     2 Car Garage   289900  Albuquerque
# 2          No Info   155000  Albuquerque
# 3     2 Car Garage   269900  Albuquerque
# 4     2 Car Garage   450000  Albuquerque
# ...            ...      ...          ...
# 6241  Open Parking   829900   Washington
# 6242  1 Car Garage   549900   Washington
# 6243  1 Car Garage   319500   Washington
# 6244  2 Car Garage  1375000   Washington
# 6245          None   387000   Washington
#
# [6246 rows x 8 columns]

# %% [markdown]
# ###  Area Data : Cut ',' string element

# %%
# can use strip or replace function
df_combined['Area(Sqft)'] = df_combined['Area(Sqft)'].str.replace(',', '')
df_combined
# Out:
#                     Address Bedrooms Bathrooms Area(Sqft) Year Built  \
# 0       9400 La Playa St NE   4 Beds   3 Baths       2000       1975
# 1          460 Wesley Ct SW   4 Beds   3 Baths       2212       2003
# 2     1307 Bernardino Rd NW   2 Beds    1 Bath        815       1948
# 3       5215 Cimarron Rd NW   3 Beds   2 Baths       1600       1977
# 4     2804 Charleston St NE   4 Beds   3 Baths       2445       1963
# ...                     ...      ...       ...        ...        ...
# 6241  2232 Mount View Pl SE   3 Beds   4 Baths       1200       1933
# 6242   1111 25th St NW #304   2 Beds    1 Bath        835       2005
# 6243     922 24th St NW #5B    1 Bed    1 Bath        743       1962
# 6244   1099 22nd St NW #401   3 Beds   3 Baths       2078       1985
# 6245   2125 14th St NW #309   Studio    1 Bath        538       2007
#
#            Parking Price($)     Location
# 0     2 Car Garage   330000  Albuquerque
# 1     2 Car Garage   289900  Albuquerque
# 2          No Info   155000  Albuquerque
# 3     2 Car Garage   269900  Albuquerque
# 4     2 Car Garage   450000  Albuquerque
# ...            ...      ...          ...
# 6241  Open Parking   829900   Washington
# 6242  1 Car Garage   549900   Washington
# 6243  1 Car Garage   319500   Washington
# 6244  2 Car Garage  1375000   Washington
# 6245          None   387000   Washington
#
# [6246 rows x 8 columns]

# %% [markdown]
# ### Bedrooms Data : Cut 'Beds' string element

# %%
df_combined['Bedrooms'] = df_combined['Bedrooms'].str.strip(' Beds')
df_combined
# Out:
#                     Address Bedrooms Bathrooms Area(Sqft) Year Built  \
# 0       9400 La Playa St NE        4   3 Baths       2000       1975
# 1          460 Wesley Ct SW        4   3 Baths       2212       2003
# 2     1307 Bernardino Rd NW        2    1 Bath        815       1948
# 3       5215 Cimarron Rd NW        3   2 Baths       1600       1977
# 4     2804 Charleston St NE        4   3 Baths       2445       1963
# ...                     ...      ...       ...        ...        ...
# 6241  2232 Mount View Pl SE        3   4 Baths       1200       1933
# 6242   1111 25th St NW #304        2    1 Bath        835       2005
# 6243     922 24th St NW #5B        1    1 Bath        743       1962
# 6244   1099 22nd St NW #401        3   3 Baths       2078       1985
# 6245   2125 14th St NW #309   Studio    1 Bath        538       2007
#
#            Parking Price($)     Location
# 0     2 Car Garage   330000  Albuquerque
# 1     2 Car Garage   289900  Albuquerque
# 2          No Info   155000  Albuquerque
# 3     2 Car Garage   269900  Albuquerque
# 4     2 Car Garage   450000  Albuquerque
# ...            ...      ...          ...
# 6241  Open Parking   829900   Washington
# 6242  1 Car Garage   549900   Washington
# 6243  1 Car Garage   319500   Washington
# 6244  2 Car Garage  1375000   Washington
# 6245          None   387000   Washington
#
# [6246 rows x 8 columns]

# %%
# show summary of grouped, counted Bedrooms values
df_combined['Bedrooms'].value_counts()
# Out:
# 3         2122
# 2         1376
# 4         1312
# 5          525
# 1          473
# 6          214
# Studio      80
# 7           75
# 8           37
# 9           17
# 11           5
# 10           3
# 12           3
# 13           1
# 84           1
# 14           1
# 24           1
# Name: Bedrooms, dtype: int64

# %% [markdown]
# ###  Bedrooms Data: Change "Studio" to = 1

# %%
# Use of lambda fxn: if column has 'Studio', convert to 1 otherwise do nothing
df_combined['Bedrooms'] = df_combined['Bedrooms'].apply(lambda x: 1 if 'Studio' in x else x)
df_combined
# Out:
#                     Address Bedrooms Bathrooms Area(Sqft) Year Built  \
# 0       9400 La Playa St NE        4   3 Baths       2000       1975
# 1          460 Wesley Ct SW        4   3 Baths       2212       2003
# 2     1307 Bernardino Rd NW        2    1 Bath        815       1948
# 3       5215 Cimarron Rd NW        3   2 Baths       1600       1977
# 4     2804 Charleston St NE        4   3 Baths       2445       1963
# ...                     ...      ...       ...        ...        ...
# 6241  2232 Mount View Pl SE        3   4 Baths       1200       1933
# 6242   1111 25th St NW #304        2    1 Bath        835       2005
# 6243     922 24th St NW #5B        1    1 Bath        743       1962
# 6244   1099 22nd St NW #401        3   3 Baths       2078       1985
# 6245   2125 14th St NW #309        1    1 Bath        538       2007
#
#            Parking Price($)     Location
# 0     2 Car Garage   330000  Albuquerque
# 1     2 Car Garage   289900  Albuquerque
# 2          No Info   155000  Albuquerque
# 3     2 Car Garage   269900  Albuquerque
# 4     2 Car Garage   450000  Albuquerque
# ...            ...      ...          ...
# 6241  Open Parking   829900   Washington
# 6242  1 Car Garage   549900   Washington
# 6243  1 Car Garage   319500   Washington
# 6244  2 Car Garage  1375000   Washington
# 6245          None   387000   Washington
#
# [6246 rows x 8 columns]

# %%
# check if a certain string element is inside a dataframe
# recall that in dataframe column = key and results (entires) are values
if 'Washington' in df_combined.values:
    print('Element is in the dataframe')
# Out:
# Element is in the dataframe

# %%
# can cross-check and verify that 'Studio' is totally gone
if 'Studio' in df_combined.values:
    print('Element is in the dataframe')

# %% [markdown]
# ### Bathrooms Data : Cut 'Baths' string element

# %%
# This cut will also encompass 'Bath'
df_combined['Bathrooms'] = df_combined['Bathrooms'].str.strip(' Baths')
df_combined
# Out:
#                     Address Bedrooms Bathrooms Area(Sqft) Year Built  \
# 0       9400 La Playa St NE        4         3       2000       1975
# 1          460 Wesley Ct SW        4         3       2212       2003
# 2     1307 Bernardino Rd NW        2         1        815       1948
# 3       5215 Cimarron Rd NW        3         2       1600       1977
# 4     2804 Charleston St NE        4         3       2445       1963
# ...                     ...      ...       ...        ...        ...
# 6241  2232 Mount View Pl SE        3         4       1200       1933
# 6242   1111 25th St NW #304        2         1        835       2005
# 6243     922 24th St NW #5B        1         1        743       1962
# 6244   1099 22nd St NW #401        3         3       2078       1985
# 6245   2125 14th St NW #309        1         1        538       2007
#
#            Parking Price($)     Location
# 0     2 Car Garage   330000  Albuquerque
# 1     2 Car Garage   289900  Albuquerque
# 2          No Info   155000  Albuquerque
# 3     2 Car Garage   269900  Albuquerque
# 4     2 Car Garage   450000  Albuquerque
# ...            ...      ...          ...
# 6241  Open Parking   829900   Washington
# 6242  1 Car Garage   549900   Washington
# 6243  1 Car Garage   319500   Washington
# 6244  2 Car Garage  1375000   Washington
# 6245          None   387000   Washington
#
# [6246 rows x 8 columns]

# %% [markdown]
# ### Parking Data : yes/no

# %%
df_combined['Parking'].value_counts()
# Out:
# Garage               1623
# No Info              1136
# 2 Car Garage         1020
# Open Parking          805
# 1 Car Garage          487
# 3 Car Garage          333
# Attached Garage       158
# None                  142
# 1 Parking Spaces      134
# 4 Car Garage           80
# 1 Carport Spaces       69
# 1 Open Spaces          39
# 2 Open Spaces          37
# 2 Parking Spaces       35
# 2 Carport Spaces       28
# Carport                23
# 0 Open Spaces          17
# 6 Car Garage           14
# 5 Car Garage           11
# 4 Parking Spaces        8
# 3 Open Spaces           6
# 4 Open Spaces           5
# 5 Open Spaces           5
# 8 Car Garage            4
# 3 Parking Spaces        4
# 3 Carport Spaces        3
# 8 Parking Spaces        3
# 9 Car Garage            2
# 6 Parking Spaces        2
# 0 Carport Spaces        1
# 5 Carport Spaces        1
# 7 Car Garage            1
# 4 Carport Spaces        1
# 11 Car Garage           1
# 10 Car Garage           1
# 3.5 Car Garage          1
# 20 Car Garage           1
# 5 Parking Spaces        1
# 9 Parking Spaces        1
# 54 Carport Spaces       1
# 206 Car Garage          1
# 59 Car Garage           1
# Name: Parking, dtype: int64

# %%
# nicely group types of parking opportunities
# groupings don't fully make sense (missing 'Parking Spaces' for 'yes') but go with it...
df_combined['Parking'] = df_combined['Parking'].apply(lambda x: 'yes' if 'Garage' in x or 'Car' in x or 'Open' in x or 'Carport' in x
                                                       else 'no')
df_combined
# Out:
#                     Address Bedrooms Bathrooms Area(Sqft) Year Built Parking  \
# 0       9400 La Playa St NE        4         3       2000       1975     yes
# 1          460 Wesley Ct SW        4         3       2212       2003     yes
# 2     1307 Bernardino Rd NW        2         1        815       1948      no
# 3       5215 Cimarron Rd NW        3         2       1600       1977     yes
# 4     2804 Charleston St NE        4         3       2445       1963     yes
# ...                     ...      ...       ...        ...        ...     ...
# 6241  2232 Mount View Pl SE        3         4       1200       1933     yes
# 6242   1111 25th St NW #304        2         1        835       2005     yes
# 6243     922 24th St NW #5B        1         1        743       1962     yes
# 6244   1099 22nd St NW #401        3         3       2078       1985     yes
# 6245   2125 14th St NW #309        1         1        538       2007      no
#
#      Price($)     Location
# 0      330000  Albuquerque
# 1      289900  Albuquerque
# 2      155000  Albuquerque
# 3      269900  Albuquerque
# 4      450000  Albuquerque
# ...       ...          ...
# 6241   829900   Washington
# 6242   549900   Washington
# 6243   319500   Washington
# 6244  1375000   Washington
# 6245   387000   Washington
#
# [6246 rows x 8 columns]

# %%
df_combined['Parking'].value_counts()
# Out:
# yes    4780
# no     1466
# Name: Parking, dtype: int64

# %% [markdown]
# ###  Convert all numbers to integers

# %% [markdown]
# #### Bedrooms

# %%
# check if bedrooms column is a numeric element
is_numeric_dtype(df_combined['Bedrooms'])
# initially outputs False
# Out:
# True

# %%
# check if bedrooms column is a string element
is_string_dtype(df_combined['Bedrooms'])
# Out:
# True

# %%
# cast Bedroom data into numeric
df_combined['Bedrooms'] = df_combined['Bedrooms'].astype(int)

# %% [markdown]
# #### Bathrooms

# %%
df_combined['Bathrooms'] = df_combined['Bathrooms'].astype(int)

# %% [markdown]
# #### Area(Sqft)

# %%
df_combined['Area(Sqft)'] = df_combined['Area(Sqft)'].astype(int)

# %% [markdown]
# #### Year Built

# %%
# check if numeric
is_numeric_dtype(df_combined['Year Built'])
# initially outputs False
# Out:
# False

# %%
# try to change to numeric
df_combined['Year Built'] = df_combined['Year Built'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-88cd2b4532c8> in <module>
#       1 # try to change to numeric
# ----> 2 df_combined['Year built'] = df_combined['Year Built'].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5804         else:
#    5805             # else, only a single dtype is given
# -> 5806             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5807             return self._constructor(new_data).__finalize__(self, method="astype")
#    5808
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     412
#     413     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 414         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     415
#     416     def convert(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     590         values = self.values
#     591
# --> 592         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     593
#     594         new_values = maybe_coerce_values(new_values)
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1172         # work around NumPy brokenness, #1987
#    1173         if np.issubdtype(dtype.type, np.integer):
# -> 1174             return lib.astype_intsafe(arr, dtype)
#    1175
#    1176         # if we have a datetime/timedelta array of objects
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: 'No Info'

# %%
# Find all entries where Year Built contains 'No Info'
df_combined[df_combined['Year Built'] == 'No Info']
# So do we delete these rows or find a way to keep?  Previously removed rows with missing values.
# Out:
#                           Address  Bedrooms  Bathrooms  Area(Sqft) Year Built  \
# 10    2304 General Marshall St NE         3          2        1877    No Info
# 24         6408 Los Pueblos Pl NW         3          3        1930    No Info
# 25        2128 Altura Verde Ln NE         3          3        2060    No Info
# 33               9720 Stone St NW         3          3        2378    No Info
# 54        1705 Los Jardines Pl NW         2          2         864    No Info
# ...                           ...       ...        ...         ...        ...
# 5517       875 California St #402         2          2        1444    No Info
# 5532           960 Market St #304         1          1         344    No Info
# 5534           821 Folsom St #310         1          1         717    No Info
# 5559          72 Townsend St #707         1          2         851    No Info
# 5560          1 Hawthorne St #23A         2          2        1558    No Info
#
#      Parking Price($)       Location
# 10       yes   304900    Albuquerque
# 24       yes   250000    Albuquerque
# 25       yes   299900    Albuquerque
# 33       yes   314900    Albuquerque
# 54       yes   159000    Albuquerque
# ...      ...      ...            ...
# 5517     yes  2320000  San Francisco
# 5532      no   520000  San Francisco
# 5534      no   779000  San Francisco
# 5559     yes  1250000  San Francisco
# 5560     yes  1950000  San Francisco
#
# [103 rows x 8 columns]

# %%
# Another option: replace with a '0'
df_combined['Year Built'] = df_combined['Year Built'].apply(lambda x: 0 if 'No Info' in x else x)
# get error message: argument of type 'float' is not iterable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-16cbe23cd150> in <module>
#       1 # Another option: replace with a '0'
# ----> 2 df_combined['Year Built'] = df_combined['Year Built'].apply(lambda x: 0 if 'No Info' in x else x)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4354         dtype: float64
#    4355         """
# -> 4356         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4357
#    4358     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1034             return self.apply_str()
#    1035
# -> 1036         return self.apply_standard()
#    1037
#    1038     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1090                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1091                 # "Callable[[Any], Any]"
# -> 1092                 mapped = lib.map_infer(
#    1093                     values,
#    1094                     f,  # type: ignore[arg-type]
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-58-16cbe23cd150> in <lambda>(x)
#       1 # Another option: replace with a '0'
# ----> 2 df_combined['Year Built'] = df_combined['Year Built'].apply(lambda x: 0 if 'No Info' in x else x)
#
# TypeError: argument of type 'float' is not iterable

# %%
# Let's try instead to first save results in a string
df_combined['Year Built'] = df_combined['Year Built'].astype(str)

# %%
# look at unique value counts
df_combined['Year Built'].value_counts()
# ahhh we have float-like values (althought these are strings)
# Out:
# 2021.0    306
# 2021      175
# 1925      156
# 1900      153
# 1920      144
#          ...
# 1876        1
# 1875.0      1
# 1903        1
# 1893.0      1
# 1874        1
# Name: Year Built, Length: 288, dtype: int64

# %%
# use lambda to replace (string) floats with empty string
df_combined['Year Built'] = df_combined['Year Built'].apply(lambda x: x.replace('.0', '') if '.0' in x else x)
df_combined['Year Built'].value_counts()
# Out:
# 2021    481
# 1900    210
# 1920    191
# 1925    184
# 2006    157
#        ...
# 1809      1
# 1752      1
# 1876      1
# 1834      1
# 1874      1
# Name: Year Built, Length: 157, dtype: int64

# %%
# NOW let's try replacing 'No Info' with a '0'
df_combined['Year Built'] = df_combined['Year Built'].apply(lambda x: 0 if 'No Info' in x else x)

# %%
# And now save as integer
df_combined['Year Built'] = df_combined['Year Built'].astype(int)

# %%
# Cross-check to verify that this coumn is now numeric
is_numeric_dtype(df_combined['Year Built'])
# Out:
# True

# %% [markdown]
# #### Price in $

# %%
is_numeric_dtype(df_combined['Price($)'])
# Out:
# False

# %%
# Try to save as integer
df_combined['Price($)'] = df_combined['Price($)'].astype(int)
# get error: invalid literal for int() with  base 10: '294900+' so some entries have a plus sign
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-815de9011fba> in <module>
#       1 # Try to save as integer
# ----> 2 df_combined['Price($)'] = df_combined['Price($)'].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5804         else:
#    5805             # else, only a single dtype is given
# -> 5806             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5807             return self._constructor(new_data).__finalize__(self, method="astype")
#    5808
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     412
#     413     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 414         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     415
#     416     def convert(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     590         values = self.values
#     591
# --> 592         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     593
#     594         new_values = maybe_coerce_values(new_values)
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1172         # work around NumPy brokenness, #1987
#    1173         if np.issubdtype(dtype.type, np.integer):
# -> 1174             return lib.astype_intsafe(arr, dtype)
#    1175
#    1176         # if we have a datetime/timedelta array of objects
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '294900+'

# %%
# Let's trim off this plus sign
df_combined['Price($)'] = df_combined['Price($)'].apply(lambda x: x.replace('+', '') if '+' in x else x)

# %%
# And try to cast into integer again
df_combined['Price($)'] = df_combined['Price($)'].astype(int)

# %%
# verify this is now a numeric data type
is_numeric_dtype(df_combined['Price($)'])
# Out:
# True

# %% [markdown]
# ###  New Column 'price/sqft'

# %%
df_combined['price/sqft'] = df_combined['Price($)']/df_combined['Area(Sqft)']

# %%
df_combined
# we now have an extra column (price/sqft) but want to round to 2 decimal places
# Out:
#                     Address  Bedrooms  Bathrooms  Area(Sqft)  Year Built  \
# 0       9400 La Playa St NE         4          3        2000        1975
# 1          460 Wesley Ct SW         4          3        2212        2003
# 2     1307 Bernardino Rd NW         2          1         815        1948
# 3       5215 Cimarron Rd NW         3          2        1600        1977
# 4     2804 Charleston St NE         4          3        2445        1963
# ...                     ...       ...        ...         ...         ...
# 6241  2232 Mount View Pl SE         3          4        1200        1933
# 6242   1111 25th St NW #304         2          1         835        2005
# 6243     922 24th St NW #5B         1          1         743        1962
# 6244   1099 22nd St NW #401         3          3        2078        1985
# 6245   2125 14th St NW #309         1          1         538        2007
#
#      Parking  Price($)     Location  Year built  price/sqft
# 0        yes    330000  Albuquerque        1975  165.000000
# 1        yes    289900  Albuquerque        2003  131.057866
# 2         no    155000  Albuquerque        1948  190.184049
# 3        yes    269900  Albuquerque        1977  168.687500
# 4        yes    450000  Albuquerque        1963  184.049080
# ...      ...       ...          ...         ...         ...
# 6241     yes    829900   Washington        1933  691.583333
# 6242     yes    549900   Washington        2005  658.562874
# 6243     yes    319500   Washington        1962  430.013459
# 6244     yes   1375000   Washington        1985  661.693936
# 6245      no    387000   Washington        2007  719.330855
#
# [6246 rows x 10 columns]

# %%
df_combined['price/sqft'] = df_combined['price/sqft'].round(2)
df_combined
# Out:
#                     Address  Bedrooms  Bathrooms  Area(Sqft)  Year Built  \
# 0       9400 La Playa St NE         4          3        2000        1975
# 1          460 Wesley Ct SW         4          3        2212        2003
# 2     1307 Bernardino Rd NW         2          1         815        1948
# 3       5215 Cimarron Rd NW         3          2        1600        1977
# 4     2804 Charleston St NE         4          3        2445        1963
# ...                     ...       ...        ...         ...         ...
# 6241  2232 Mount View Pl SE         3          4        1200        1933
# 6242   1111 25th St NW #304         2          1         835        2005
# 6243     922 24th St NW #5B         1          1         743        1962
# 6244   1099 22nd St NW #401         3          3        2078        1985
# 6245   2125 14th St NW #309         1          1         538        2007
#
#      Parking  Price($)     Location  Year built  price/sqft
# 0        yes    330000  Albuquerque        1975      165.00
# 1        yes    289900  Albuquerque        2003      131.06
# 2         no    155000  Albuquerque        1948      190.18
# 3        yes    269900  Albuquerque        1977      168.69
# 4        yes    450000  Albuquerque        1963      184.05
# ...      ...       ...          ...         ...         ...
# 6241     yes    829900   Washington        1933      691.58
# 6242     yes    549900   Washington        2005      658.56
# 6243     yes    319500   Washington        1962      430.01
# 6244     yes   1375000   Washington        1985      661.69
# 6245      no    387000   Washington        2007      719.33
#
# [6246 rows x 10 columns]

# %% [markdown]
# ### Check for outliers

# %%
df_combined['price/sqft'].describe()
# mix and max values seem pretty extreme
# Out:
# count      6246.000000
# mean        616.918277
# std        7205.666641
# min           0.440000
# 25%         189.710000
# 50%         311.160000
# 75%         596.375000
# max      560000.000000
# Name: price/sqft, dtype: float64

# %%
# Locate entries where price/sqft is less than 10
df_combined.loc[df_combined['price/sqft'] < 10]
# dang.  cross-check an address to visually verify in online listing
# decide if wish to keep or remove
# Out:
#                  Address  Bedrooms  Bathrooms  Area(Sqft)  Year Built Parking  \
# 1144   1216 E Vermont St         3          3        4317        1880      no
# 1470    3135 Ralston Ave         1          1        1214        1910      no
# 3309   21-77 33rd St #4G         2          1      430000        1923      no
# 3448  60 Knolls Cres #1J         3          1      237800        1953     yes
# 3734  72-61 113th St #5B         1          1      137820        1951     yes
#
#       Price($)      Location  Year built  price/sqft
# 1144      1895  Indianapolis        1880        0.44
# 1470      6000  Indianapolis        1910        4.94
# 3309    329000      New York        1923        0.77
# 3448    190162      New York        1953        0.80
# 3734    178000      New York        1951        1.29

# %%
# Locate entries where price/sqft equals 560000
df_combined.loc[df_combined['price/sqft'] == 560000]
# my stars.  can cross-check address online, note lists sqft = 1, so likely listing error
# Out:
#              Address  Bedrooms  Bathrooms  Area(Sqft)  Year Built Parking  \
# 3564  3069 Heath Ave         3          2           1        1899      no
#
#       Price($)  Location  Year built  price/sqft
# 3564    560000  New York        1899    560000.0

# %%
# drop this outlier
df_combined = df_combined.drop(3564)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-67c2938190cb> in <module>
#       1 # drop this outlier
# ----> 2 df_combined = df_combined.drop(3564)
#       3 df_combined
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4899                 weight  1.0     0.8
#    4900         """
# -> 4901         return super().drop(
#    4902             labels=labels,
#    4903             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4145         for axis, labels in axes.items():
#    4146             if labels is not None:
# -> 4147                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4148
#    4149         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4180                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4181             else:
# -> 4182                 new_axis = axis.drop(labels, errors=errors)
#    4183             result = self.reindex(**{axis_name: new_axis})
#    4184
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6016         if mask.any():
#    6017             if errors != "ignore":
# -> 6018                 raise KeyError(f"{labels[mask]} not found in axis")
#    6019             indexer = indexer[~mask]
#    6020         return self.delete(indexer)
#
# KeyError: '[3564] not found in axis'

# %%
# and now there is 1 row less in dataframe
df_combined
# Out:
#                     Address  Bedrooms  Bathrooms  Area(Sqft)  Year Built  \
# 0       9400 La Playa St NE         4          3        2000        1975
# 1          460 Wesley Ct SW         4          3        2212        2003
# 2     1307 Bernardino Rd NW         2          1         815        1948
# 3       5215 Cimarron Rd NW         3          2        1600        1977
# 4     2804 Charleston St NE         4          3        2445        1963
# ...                     ...       ...        ...         ...         ...
# 6241  2232 Mount View Pl SE         3          4        1200        1933
# 6242   1111 25th St NW #304         2          1         835        2005
# 6243     922 24th St NW #5B         1          1         743        1962
# 6244   1099 22nd St NW #401         3          3        2078        1985
# 6245   2125 14th St NW #309         1          1         538        2007
#
#      Parking  Price($)     Location  Year built  price/sqft
# 0        yes    330000  Albuquerque        1975      165.00
# 1        yes    289900  Albuquerque        2003      131.06
# 2         no    155000  Albuquerque        1948      190.18
# 3        yes    269900  Albuquerque        1977      168.69
# 4        yes    450000  Albuquerque        1963      184.05
# ...      ...       ...          ...         ...         ...
# 6241     yes    829900   Washington        1933      691.58
# 6242     yes    549900   Washington        2005      658.56
# 6243     yes    319500   Washington        1962      430.01
# 6244     yes   1375000   Washington        1985      661.69
# 6245      no    387000   Washington        2007      719.33
#
# [6245 rows x 10 columns]

# %% [markdown]
# ###  Save in Excel

# %%
df_combined.to_excel('cleaned_data.xlsx', index = False)
