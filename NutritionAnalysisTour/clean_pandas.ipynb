# %% [markdown]
# # Nutrition Analysis Tour
# ## Cleaning initial .csv file using pandas

# %%
import pandas as pd

# %%
sb_clean = pd.read_csv("starbucks_drink_menu.csv")
sb_clean.head()
# Out:
#          Beverage_category     Beverage      Beverage_prep  Calories  \
# 0  Classic Espresso Drinks  Caffè Latte  Short Nonfat Milk        70
# 1  Classic Espresso Drinks  Caffè Latte            2% Milk       100
# 2  Classic Espresso Drinks  Caffè Latte            Soymilk        70
# 3  Classic Espresso Drinks  Caffè Latte   Tall Nonfat Milk       100
# 4  Classic Espresso Drinks  Caffè Latte            2% Milk       150
#
#    Total Fat (g)  Trans Fat (g)   Saturated Fat (g)   Sodium (mg)  \
# 0            0.1             0.1                0.0             5
# 1            3.5             2.0                0.1            15
# 2            2.5             0.4                0.0             0
# 3            0.2             0.2                0.0             5
# 4              6             3.0                0.2            25
#
#     Total Carbohydrates (g)   Cholesterol (mg)   Dietary Fibre (g)  \
# 0                         75                10                   0
# 1                         85                10                   0
# 2                         65                 6                   1
# 3                        120                15                   0
# 4                        135                15                   0
#
#     Sugars (g)   Protein (g)  Vitamin A (% DV)  Vitamin C (% DV)  \
# 0            9            6.0               10%               0%
# 1            9            6.0               10%               0%
# 2            4            5.0                6%               0%
# 3           14           10.0               15%               0%
# 4           14           10.0               15%               0%
#
#    Calcium (% DV)  Iron (% DV)  Caffeine (mg)
# 0              20%           0%            75
# 1              20%           0%            75
# 2              20%           8%            75
# 3              30%           0%            75
# 4              30%           0%            75

# %%
# Let's see what we are up against here 
# check for missing data & data types
sb_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Beverage_category          240 non-null    object
#  1   Beverage                   240 non-null    object
#  2   Beverage_prep              240 non-null    object
#  3   Calories                   240 non-null    int64
#  4    Total Fat (g)             240 non-null    object
#  5   Trans Fat (g)              240 non-null    float64
#  6   Saturated Fat (g)          240 non-null    float64
#  7    Sodium (mg)               240 non-null    int64
#  8    Total Carbohydrates (g)   240 non-null    int64
#  9   Cholesterol (mg)           240 non-null    int64
#  10   Dietary Fibre (g)         240 non-null    int64
#  11   Sugars (g)                240 non-null    int64
#  12   Protein (g)               240 non-null    float64
#  13  Vitamin A (% DV)           240 non-null    object
#  14  Vitamin C (% DV)           240 non-null    object
#  15   Calcium (% DV)            240 non-null    object
#  16  Iron (% DV)                240 non-null    object
#  17  Caffeine (mg)              239 non-null    object
# dtypes: float64(3), int64(6), object(9)
# memory usage: 33.9+ KB

# %%
# check for at least 1 missing value in a row
sb_clean[sb_clean.isna().any(axis = 1)]
# observation of data in this region: the same drink (with other milk types) contains 90mg caffeine, will add in this value
# Out:
#          Beverage_category                                        Beverage  \
# 133  Shaken Iced Beverages  Iced Brewed Coffee (With Milk & Classic Syrup)
#
#     Beverage_prep  Calories  Total Fat (g)  Trans Fat (g)   Saturated Fat (g)  \
# 133       2% Milk        90              1             0.5                0.0
#
#       Sodium (mg)   Total Carbohydrates (g)   Cholesterol (mg)  \
# 133             5                         25                18
#
#       Dietary Fibre (g)   Sugars (g)   Protein (g)  Vitamin A (% DV)   \
# 133                   0           18            2.0                2%
#
#     Vitamin C (% DV)  Calcium (% DV)  Iron (% DV)  Caffeine (mg)
# 133               0%               6%        0.00%           NaN

# %%
# add missing caffeine value
sb_clean["Caffeine (mg)"].replace([None], [90], inplace = True)

# %%
sb_clean.loc[158, "Caffeine (mg)"]
# Out:
# '130'

# %%
# check for duplicates
sb_clean.duplicated().sum()
# Out:
# 0

# %%
# Clean up header names (lowercase with underscore)
# haha!  White spaces abount in column header names.  I learned a valuable lesson.
dict = {"Beverage_category":"category", "Beverage":"name", "Beverage_prep":"prep", "Calories":"calories", " Total Fat (g)":"total_fat_g", "Trans Fat (g) ":"trans_fat_g", 
        "Saturated Fat (g)":"sat_fat_g", " Sodium (mg)":"sodium_mg", " Total Carbohydrates (g) ":"carbs_g", "Cholesterol (mg)":"chol_mg", " Dietary Fibre (g)":"fiber_g",
        " Sugars (g)":"sugars_g", " Protein (g) ":"protein_g", "Vitamin A (% DV) ":"vit_a_%dv", "Vitamin C (% DV)":"vit_c_%dv", " Calcium (% DV) ":"calcium_%dv", 
        "Iron (% DV) ":"iron_%dv", "Caffeine (mg)":"caffeine_mg"
}
sb_clean.rename(columns = dict, inplace = True)
sb_clean.head()
# Out:
#                   category         name               prep  calories  \
# 0  Classic Espresso Drinks  Caffè Latte  Short Nonfat Milk        70
# 1  Classic Espresso Drinks  Caffè Latte            2% Milk       100
# 2  Classic Espresso Drinks  Caffè Latte            Soymilk        70
# 3  Classic Espresso Drinks  Caffè Latte   Tall Nonfat Milk       100
# 4  Classic Espresso Drinks  Caffè Latte            2% Milk       150
#
#   total_fat_g  trans_fat_g  sat_fat_g  sodium_mg  carbs_g  chol_mg  fiber_g  \
# 0         0.1          0.1        0.0          5       75       10        0
# 1         3.5          2.0        0.1         15       85       10        0
# 2         2.5          0.4        0.0          0       65        6        1
# 3         0.2          0.2        0.0          5      120       15        0
# 4           6          3.0        0.2         25      135       15        0
#
#    sugars_g  protein_g vit_a_%dv vit_c_%dv calcium_%dv iron_%dv caffeine_mg
# 0         9        6.0       10%        0%         20%       0%          75
# 1         9        6.0       10%        0%         20%       0%          75
# 2         4        5.0        6%        0%         20%       8%          75
# 3        14       10.0       15%        0%         30%       0%          75
# 4        14       10.0       15%        0%         30%       0%          75

# %%
# remove extraneous % symbol
sb_clean['vit_a_%dv'] = sb_clean['vit_a_%dv'].str.strip('%')
sb_clean['vit_c_%dv'] = sb_clean['vit_c_%dv'].str.strip('%')
sb_clean['calcium_%dv'] = sb_clean['calcium_%dv'].str.strip('%')
sb_clean['iron_%dv'] = sb_clean['iron_%dv'].str.strip('%')
sb_clean
# Out:
#                     category                                     name  \
# 0    Classic Espresso Drinks                              Caffè Latte
# 1    Classic Espresso Drinks                              Caffè Latte
# 2    Classic Espresso Drinks                              Caffè Latte
# 3    Classic Espresso Drinks                              Caffè Latte
# 4    Classic Espresso Drinks                              Caffè Latte
# ..                       ...                                      ...
# 235         Tazo® Tea Drinks                                Tazo® Tea
# 236         Tazo® Tea Drinks                                Tazo® Tea
# 237    Shaken Iced Beverages  Iced Brewed Coffee (With Classic Syrup)
# 238    Shaken Iced Beverages  Iced Brewed Coffee (With Classic Syrup)
# 239    Shaken Iced Beverages  Iced Brewed Coffee (With Classic Syrup)
#
#                   prep  calories total_fat_g  trans_fat_g  sat_fat_g  \
# 0    Short Nonfat Milk        70         0.1          0.1        0.0
# 1              2% Milk       100         3.5          2.0        0.1
# 2              Soymilk        70         2.5          0.4        0.0
# 3     Tall Nonfat Milk       100         0.2          0.2        0.0
# 4              2% Milk       150           6          3.0        0.2
# ..                 ...       ...         ...          ...        ...
# 235             Grande         0           0          0.0        0.0
# 236              Venti         0           0          0.0        0.0
# 237               Tall        60           0          0.0        0.0
# 238             Grande        90         0.1          0.0        0.0
# 239              Venti       130         0.1          0.0        0.0
#
#      sodium_mg  carbs_g  chol_mg  fiber_g  sugars_g  protein_g vit_a_%dv  \
# 0            5       75       10        0         9        6.0        10
# 1           15       85       10        0         9        6.0        10
# 2            0       65        6        1         4        5.0         6
# 3            5      120       15        0        14       10.0        15
# 4           25      135       15        0        14       10.0        15
# ..         ...      ...      ...      ...       ...        ...       ...
# 235          0        0        0        0         0        0.0         0
# 236          0        0        0        0         0        0.0         0
# 237          0        4       15        0        15        0.2         0
# 238          0        5       21        0        21        0.3         0
# 239          0        5       31        0        31        0.4         0
#
#     vit_c_%dv calcium_%dv iron_%dv caffeine_mg
# 0           0          20        0          75
# 1           0          20        0          75
# 2           0          20        8          75
# 3           0          30        0          75
# 4           0          30        0          75
# ..        ...         ...      ...         ...
# 235         0           0        0      Varies
# 236         0           0        0      Varies
# 237         0           0        0         120
# 238         0           0        0         165
# 239         0           0        0         235
#
# [240 rows x 18 columns]

# %%
# now verify that these columns contain only integer-like strings for vitamins/minerals and caffeine
sb_clean['iron_%dv'].value_counts()
# ooo gross random floats, fix it!
# Out:
# 0        97
# 2        20
# 10       17
# 20       16
# 8        15
# 6        14
# 15       11
# 4        11
# 30        9
# 25        9
# 0.00      9
# 40        3
# 35        3
# 50        2
# 6.00      1
# 8.00      1
# 10.00     1
# 15.00     1
# Name: iron_%dv, dtype: int64

# %%
sb_clean['iron_%dv'] = sb_clean['iron_%dv'].apply(lambda x: x.replace('.00', '') if '.00' in x else x)

# %%
sb_clean['iron_%dv'].value_counts()
# Out:
# 0     106
# 2      20
# 10     18
# 8      16
# 20     16
# 6      15
# 15     12
# 4      11
# 25      9
# 30      9
# 40      3
# 35      3
# 50      2
# Name: iron_%dv, dtype: int64

# %%
sb_clean['caffeine_mg'].value_counts()
# Alas.  A mg value of "varies" is less than useless, so we will omit this data.
# Out:
# 75        36
# 0         35
# 150       33
# 70        14
# varies    12
# 95        11
# Varies     9
# 110        9
# 130        7
# 120        6
# 25         6
# 15         4
# 90         4
# 175        4
# 55         3
# 170        3
# 85         3
# 145        3
# 80         3
# 140        3
# 180        3
# 100        3
# 125        3
# 10         3
# 20         3
# 30         3
# 50         3
# 165        2
# 90         1
# 260        1
# 330        1
# 410        1
# 225        1
# 300        1
# 65         1
# 105        1
# 235        1
# Name: caffeine_mg, dtype: int64

# %%
# Filtering data to remove non-numeric caffeine values
sb_clean = sb_clean[sb_clean['caffeine_mg'] != 'varies']
sb_clean = sb_clean[sb_clean['caffeine_mg'] != 'Varies']
sb_clean['caffeine_mg'].value_counts()
# Out:
# 75     36
# 0      35
# 150    33
# 70     14
# 95     11
# 110     9
# 130     7
# 25      6
# 120     6
# 15      4
# 90      4
# 175     4
# 50      3
# 125     3
# 145     3
# 100     3
# 30      3
# 85      3
# 170     3
# 140     3
# 180     3
# 10      3
# 20      3
# 80      3
# 55      3
# 165     2
# 90      1
# 260     1
# 330     1
# 410     1
# 225     1
# 300     1
# 65      1
# 105     1
# 235     1
# Name: caffeine_mg, dtype: int64

# %%
# cast vitamin/mineral data type from object to int
sb_clean['vit_a_%dv'] = sb_clean['vit_a_%dv'].astype(int)
sb_clean['vit_c_%dv'] = sb_clean['vit_c_%dv'].astype(int)
sb_clean['calcium_%dv'] = sb_clean['calcium_%dv'].astype(int)
sb_clean['iron_%dv'] = sb_clean['iron_%dv'].astype(int)
sb_clean['caffeine_mg'] = sb_clean['caffeine_mg'].astype(int)
sb_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 219 entries, 0 to 239
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   category     219 non-null    object
#  1   name         219 non-null    object
#  2   prep         219 non-null    object
#  3   calories     219 non-null    int64
#  4   total_fat_g  219 non-null    object
#  5   trans_fat_g  219 non-null    float64
#  6   sat_fat_g    219 non-null    float64
#  7   sodium_mg    219 non-null    int64
#  8   carbs_g      219 non-null    int64
#  9   chol_mg      219 non-null    int64
#  10  fiber_g      219 non-null    int64
#  11  sugars_g     219 non-null    int64
#  12  protein_g    219 non-null    float64
#  13  vit_a_%dv    219 non-null    int32
#  14  vit_c_%dv    219 non-null    int32
#  15  calcium_%dv  219 non-null    int32
#  16  iron_%dv     219 non-null    int32
#  17  caffeine_mg  219 non-null    int32
# dtypes: float64(3), int32(5), int64(6), object(4)
# memory usage: 28.2+ KB

# %%
# Normalize prep column: add column for milk type
sb_clean.insert(3, "milk_type", sb_clean["prep"])

# %%
sb_clean.head(15)
# Out:
#                    category                                 name  \
# 0   Classic Espresso Drinks                          Caffè Latte
# 1   Classic Espresso Drinks                          Caffè Latte
# 2   Classic Espresso Drinks                          Caffè Latte
# 3   Classic Espresso Drinks                          Caffè Latte
# 4   Classic Espresso Drinks                          Caffè Latte
# 5   Classic Espresso Drinks                          Caffè Latte
# 6   Classic Espresso Drinks                          Caffè Latte
# 7   Classic Espresso Drinks                          Caffè Latte
# 8   Classic Espresso Drinks                          Caffè Latte
# 9   Classic Espresso Drinks                          Caffè Latte
# 10  Classic Espresso Drinks                          Caffè Latte
# 11  Classic Espresso Drinks                          Caffè Latte
# 12  Classic Espresso Drinks  Caffè Mocha (Without Whipped Cream)
# 13  Classic Espresso Drinks  Caffè Mocha (Without Whipped Cream)
# 14  Classic Espresso Drinks  Caffè Mocha (Without Whipped Cream)
#
#                   prep           milk_type  calories total_fat_g  trans_fat_g  \
# 0    Short Nonfat Milk   Short Nonfat Milk        70         0.1          0.1
# 1              2% Milk             2% Milk       100         3.5          2.0
# 2              Soymilk             Soymilk        70         2.5          0.4
# 3     Tall Nonfat Milk    Tall Nonfat Milk       100         0.2          0.2
# 4              2% Milk             2% Milk       150           6          3.0
# 5              Soymilk             Soymilk       110         4.5          0.5
# 6   Grande Nonfat Milk  Grande Nonfat Milk       130         0.3          0.2
# 7              2% Milk             2% Milk       190           7          3.5
# 8              Soymilk             Soymilk       150           5          0.5
# 9    Venti Nonfat Milk   Venti Nonfat Milk       170         0.4          0.3
# 10             2% Milk             2% Milk       240           9          4.5
# 11             Soymilk             Soymilk       190           7          1.0
# 12   Short Nonfat Milk   Short Nonfat Milk       110         1.5          1.0
# 13             2% Milk             2% Milk       130           4          2.0
# 14             Soymilk             Soymilk       110         3.5          1.0
#
#     sat_fat_g  sodium_mg  carbs_g  chol_mg  fiber_g  sugars_g  protein_g  \
# 0         0.0          5       75       10        0         9        6.0
# 1         0.1         15       85       10        0         9        6.0
# 2         0.0          0       65        6        1         4        5.0
# 3         0.0          5      120       15        0        14       10.0
# 4         0.2         25      135       15        0        14       10.0
# 5         0.0          0      105       10        1         6        8.0
# 6         0.0          5      150       19        0        18       13.0
# 7         0.2         30      170       19        0        17       12.0
# 8         0.0          0      130       13        1         8       10.0
# 9         0.0         10      190       25        0        23       16.0
# 10        0.3         35      220       24        0        22       16.0
# 11        0.0          0      170       16        2        11       13.0
# 12        0.0          5       60       21        1        17        7.0
# 13        0.1         10       70       21        1        17        6.0
# 14        0.0          0       55       19        2        13        6.0
#
#     vit_a_%dv  vit_c_%dv  calcium_%dv  iron_%dv  caffeine_mg
# 0          10          0           20         0           75
# 1          10          0           20         0           75
# 2           6          0           20         8           75
# 3          15          0           30         0           75
# 4          15          0           30         0           75
# 5          10          0           30        15           75
# 6          20          0           40         0          150
# 7          20          2           40         0          150
# 8          15          0           40        15          150
# 9          30          0           50         0          150
# 10         25          2           50         0          150
# 11         20          0           50        25          150
# 12          8          0           15        10           85
# 13          8          0           15        10           85
# 14          6          0           15        20           85

# %%
# Using lambdas to update milk_type with selection of soy, 2%, whole, or nonfat
sb_clean['milk_type'] = sb_clean['milk_type'].apply(lambda x: 'Soy' if 'Soy' in x else x)
sb_clean['milk_type'] = sb_clean['milk_type'].apply(lambda x: 'Nonfat' if 'Nonfat' in x else x)
sb_clean['milk_type'] = sb_clean['milk_type'].apply(lambda x: '2%' if '2%' in x else x)
sb_clean['milk_type'] = sb_clean['milk_type'].apply(lambda x: 'Whole' if 'Whole Milk' in x else x)
sb_clean['milk_type'].value_counts()
# Out:
# Nonfat    79
# Soy       62
# 2%        46
# Whole     16
# Tall       5
# Grande     4
# Venti      4
# Short      3
# Name: milk_type, dtype: int64

# %%
# Remove extraneous descriptors besides types of milk
sb_clean['milk_type'] = sb_clean['milk_type'].apply(lambda x: '' if 'Tall' in x or 'Grande' in x or 'Venti' in x or 'Short' in x or 'Solo' in x or 'Doppio' in x else x)
sb_clean['milk_type'].value_counts()
# Out:
# Nonfat    79
# Soy       62
# 2%        46
# Whole     16
#           16
# Name: milk_type, dtype: int64

# %%
# Normalize prep column: add column for size_oz
sb_clean.insert(3, "size_oz", sb_clean["prep"])
sb_clean.head()
# Out:
#                   category         name               prep            size_oz  \
# 0  Classic Espresso Drinks  Caffè Latte  Short Nonfat Milk  Short Nonfat Milk
# 1  Classic Espresso Drinks  Caffè Latte            2% Milk            2% Milk
# 2  Classic Espresso Drinks  Caffè Latte            Soymilk            Soymilk
# 3  Classic Espresso Drinks  Caffè Latte   Tall Nonfat Milk   Tall Nonfat Milk
# 4  Classic Espresso Drinks  Caffè Latte            2% Milk            2% Milk
#
#   milk_type  calories total_fat_g  trans_fat_g  sat_fat_g  sodium_mg  carbs_g  \
# 0    Nonfat        70         0.1          0.1        0.0          5       75
# 1        2%       100         3.5          2.0        0.1         15       85
# 2       Soy        70         2.5          0.4        0.0          0       65
# 3    Nonfat       100         0.2          0.2        0.0          5      120
# 4        2%       150           6          3.0        0.2         25      135
#
#    chol_mg  fiber_g  sugars_g  protein_g  vit_a_%dv  vit_c_%dv  calcium_%dv  \
# 0       10        0         9        6.0         10          0           20
# 1       10        0         9        6.0         10          0           20
# 2        6        1         4        5.0          6          0           20
# 3       15        0        14       10.0         15          0           30
# 4       15        0        14       10.0         15          0           30
#
#    iron_%dv  caffeine_mg
# 0         0           75
# 1         0           75
# 2         8           75
# 3         0           75
# 4         0           75

# %%
sb_clean_slice = sb_clean.loc[0:197]
sb_clean_slice.tail(10)
# Out:
#                        category                                          name  \
# 188  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 189  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 190  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 191  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 192  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 193  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 194  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 195  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 196  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 197  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
#                    prep             size_oz milk_type  calories total_fat_g  \
# 188             Soymilk             Soymilk       Soy       170         1.5
# 189  Grande Nonfat Milk  Grande Nonfat Milk    Nonfat       230         0.2
# 190          Whole Milk          Whole Milk     Whole       260           4
# 191             Soymilk             Soymilk       Soy       240           2
# 192   Venti Nonfat Milk   Venti Nonfat Milk    Nonfat       310         0.2
# 193          Whole Milk          Whole Milk     Whole       350           6
# 194             Soymilk             Soymilk       Soy       320         3 2
# 195    Tall Nonfat Milk    Tall Nonfat Milk    Nonfat       170         0.1
# 196          Whole Milk          Whole Milk     Whole       200         3.5
# 197             Soymilk             Soymilk       Soy       180         1.5
#
#      trans_fat_g  sat_fat_g  sodium_mg  carbs_g  chol_mg  fiber_g  sugars_g  \
# 188          0.2        0.0          0      135       37        1        35
# 189          0.1        0.0          0      190       53        0        52
# 190          2.0        0.1         10      190       53        0        52
# 191          0.2        0.0          0      180       51        1        49
# 192          0.1        0.0          5      260       70        0        69
# 193          3.0        0.2         15      260       70        0        68
# 194          0.4        0.0          0      250       67        1        64
# 195          0.1        0.0          0      160       39        0        38
# 196          2.0        0.1         10      160       39        0        38
# 197          0.2        0.0          0      160       37        1        35
#
#      protein_g  vit_a_%dv  vit_c_%dv  calcium_%dv  iron_%dv  caffeine_mg
# 188        3.0          4          6           10         6            0
# 189        4.0          8          6           15         4            0
# 190        4.0          6          6           15         4            0
# 191        3.0          4          6           15         8            0
# 192        6.0         10          8           20         4            0
# 193        6.0          8          8           20         4            0
# 194        5.0          6          8           20        10            0
# 195        4.0          6          0           10         0            0
# 196        3.0          6          0           10         0            0
# 197        3.0          4          0           10         6            0

# %%
sb_clean_slice.loc[sb_clean_slice['prep'].shift(+1).eq('Short Nonfat Milk'), 'size_oz'] = 8
sb_clean_slice.loc[sb_clean_slice['prep'].shift(+2).eq('Short Nonfat Milk'), 'size_oz'] = 8
sb_clean_slice.loc[sb_clean_slice['prep'].shift(+1).eq('Tall Nonfat Milk'), 'size_oz'] = 12
sb_clean_slice.loc[sb_clean_slice['prep'].shift(+2).eq('Tall Nonfat Milk'), 'size_oz'] = 12
sb_clean_slice.loc[sb_clean_slice['prep'].shift(+1).eq('Venti Nonfat Milk'), 'size_oz'] = 16
sb_clean_slice.loc[sb_clean_slice['prep'].shift(+2).eq('Venti Nonfat Milk'), 'size_oz'] = 16
sb_clean_slice.loc[sb_clean_slice['prep'].shift(+1).eq('Grande Nonfat Milk'), 'size_oz'] = 20
sb_clean_slice.loc[sb_clean_slice['prep'].shift(+2).eq('Grande Nonfat Milk'), 'size_oz'] = 20

# %%
sb_clean['size_oz'].value_counts()
# Out:
# 20                    38
# 12                    34
# 16                    32
# Grande Nonfat Milk    25
# Tall Nonfat Milk      22
# Venti Nonfat Milk     21
# 8                     20
# Short Nonfat Milk     11
# Tall                   5
# Grande                 4
# Venti                  4
# Short                  3
# Name: size_oz, dtype: int64

# %%
# Using replace() to update values 

sb_clean['size_oz'].replace(["Short", "Short Nonfat Milk"], 8, inplace = True)
sb_clean['size_oz'].replace(["Tall", "Tall Nonfat Milk"], 12, inplace = True)
sb_clean['size_oz'].replace(["Grande", "Grande Nonfat Milk"], 16, inplace = True)
sb_clean['size_oz'].replace(["Venti", "Venti Nonfat Milk"], 20, inplace = True)
sb_clean['size_oz'].value_counts()
# Out:
# 20    63
# 12    61
# 16    61
# 8     34
# Name: size_oz, dtype: int64

# %%
sb_clean
# Out:
#                       category                                         name  \
# 0      Classic Espresso Drinks                                  Caffè Latte
# 1      Classic Espresso Drinks                                  Caffè Latte
# 2      Classic Espresso Drinks                                  Caffè Latte
# 3      Classic Espresso Drinks                                  Caffè Latte
# 4      Classic Espresso Drinks                                  Caffè Latte
# ..                         ...                                          ...
# 231  Signature Espresso Drinks  Caramel Apple Spice (Without Whipped Cream)
# 232  Signature Espresso Drinks  Caramel Apple Spice (Without Whipped Cream)
# 237      Shaken Iced Beverages      Iced Brewed Coffee (With Classic Syrup)
# 238      Shaken Iced Beverages      Iced Brewed Coffee (With Classic Syrup)
# 239      Shaken Iced Beverages      Iced Brewed Coffee (With Classic Syrup)
#
#                   prep  size_oz milk_type  calories total_fat_g  trans_fat_g  \
# 0    Short Nonfat Milk        8    Nonfat        70         0.1          0.1
# 1              2% Milk        8        2%       100         3.5          2.0
# 2              Soymilk        8       Soy        70         2.5          0.4
# 3     Tall Nonfat Milk       12    Nonfat       100         0.2          0.2
# 4              2% Milk       12        2%       150           6          3.0
# ..                 ...      ...       ...       ...         ...          ...
# 231             Grande       16                 280           0          0.0
# 232              Venti       20                 360           0          0.0
# 237               Tall       12                  60           0          0.0
# 238             Grande       16                  90         0.1          0.0
# 239              Venti       20                 130         0.1          0.0
#
#      sat_fat_g  sodium_mg  carbs_g  chol_mg  fiber_g  sugars_g  protein_g  \
# 0          0.0          5       75       10        0         9        6.0
# 1          0.1         15       85       10        0         9        6.0
# 2          0.0          0       65        6        1         4        5.0
# 3          0.0          5      120       15        0        14       10.0
# 4          0.2         25      135       15        0        14       10.0
# ..         ...        ...      ...      ...      ...       ...        ...
# 231        0.0          0       20       70        0        65        0.0
# 232        0.0          0       25       89        0        83        0.0
# 237        0.0          0        4       15        0        15        0.2
# 238        0.0          0        5       21        0        21        0.3
# 239        0.0          0        5       31        0        31        0.4
#
#      vit_a_%dv  vit_c_%dv  calcium_%dv  iron_%dv  caffeine_mg
# 0           10          0           20         0           75
# 1           10          0           20         0           75
# 2            6          0           20         8           75
# 3           15          0           30         0           75
# 4           15          0           30         0           75
# ..         ...        ...          ...       ...          ...
# 231          0          0            0         0            0
# 232          0          0            0         0            0
# 237          0          0            0         0          120
# 238          0          0            0         0          165
# 239          0          0            0         0          235
#
# [219 rows x 20 columns]

# %%
# Column will be cold and = 24 if Beverage_category contains “Iced”, “Smoothies” or “Blended”

# df.loc[df['val'].shift(-1).eq('yes'), 'val'] = 'yes'

# for i in range(0, 199):
#    if sb_clean.iloc[i]['prep'] == 'Short Nonfat Milk':
#        sb_clean.loc[i, ['size_oz']] = 8
#        sb_clean.loc[i+1, ['size_oz']] = 8
#        sb_clean.loc[i+2, ['size_oz']] = 8
#    elif sb_clean.iloc[i]['prep'] == 'Tall Nonfat Milk':
#        sb_clean.loc[i, ['size_oz']] = 12
#        sb_clean.loc[i+1, ['size_oz']] = 12
#        sb_clean.loc[i+2, ['size_oz']] = 12
#    elif sb_clean.iloc[i]['prep'] == 'Grande Nonfat Milk':
#        sb_clean.loc[i, ['size_oz']] = 16
#        sb_clean.loc[i+1, ['size_oz']] = 16
#        sb_clean.loc[i+2, ['size_oz']] = 16
#    elif sb_clean.iloc[i]['prep'] == 'Venti Nonfat Milk':
#        sb_clean.loc[i, ['size_oz']] = 20
#        sb_clean.loc[i+1, ['size_oz']] = 20
#        sb_clean.loc[i+2, ['size_oz']] = 20

# for i in range(0, 106):
#    if sb_clean.iloc[i]['prep'] == 'Soymilk':
#        if sb_clean.iloc[i-2]['prep'] == 'Short Nonfat Milk':
#            sb_clean.loc[i, ['size_oz']] = 8
#        elif sb_clean.iloc[i-2]['prep'] == 'Tall Nonfat Milk':
#            sb_clean.loc[i, ['size_oz']] = 12
#        elif sb_clean.iloc[i-2]['prep'] == 'Grande Nonfat Milk':
#            sb_clean.loc[i, ['size_oz']] = 16
#        elif sb_clean.iloc[i-2]['prep'] == 'Venti Nonfat Milk':
#            sb_clean.loc[i, ['size_oz']] = 20
#        else:
#             continue

# %%
# sb_clean.to_csv('sb_clean.csv', index = False)

# %%
# Add % DV calculations for Fat, Sugar, Caffeine

# %%
# Descriptive stats (here or in new NB entry)?
# which drinks have the most sugar?  Overall caffeine in tea vs coffee drinks?

# %%
# export clean csv file

# %%
# add unique ids for cat_id, name_id, type_id
